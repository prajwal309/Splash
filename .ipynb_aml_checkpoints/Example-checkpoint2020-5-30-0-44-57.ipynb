# %% [markdown]
# Import the libraries. For all the dependencies look at the installation file

# %%
import numpy as np

from lib.splash import Target
from lib.algorithm import GeneralTransitSearch

import matplotlib
SVDSearch = GeneralTransitSearch()

# %matplotlib inline

# %%
#Version=0 --->SNO format data txt file
#Version=1--->Old Cambridge Pipeline fits file
#Version=2--->New Cambridge Pipeline fits file

Target1 = Target(Location="data", Name="Sp0025+5422", Output="Sp0025+5422", version=0)
#Remove Column 1 just uses sigma clipping using flux
#Column -1 uses all of the available columns of data
Target1.PreClean(CutOff=7.5, NIter=2, Columns=-1, MinDataCount=50, SavePlot=False, ShowPlot=True)


#Load of the data

Target2 = Target(Location="data", Name="Sp0000+0000", Output="Sp0000+0000", version=0)
Target2.PreClean(CutOff=7.5, NIter=2, Columns=-1, MinDataCount=50, SavePlot=False, ShowPlot=True)
# Out:
# Loading from txt file.
# The output folder already exists. Deleting all previous files and folders within it.
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# Loading from txt file.
# --------------------------------------------------
# ValueError       Traceback (most recent call last)
# /media/prajwal/Elements/Splash/lib/Functions.py in ReadTxtData(Location, TargetName)
#     216         try:
# --> 217             Data = np.loadtxt(FileItem,skiprows=1, delimiter=",")
#     218         except:
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in floatconv(x)
#     793             return float.fromhex(x)
# --> 794         return float(x)
#     795
#
# ValueError: could not convert string to float: '8.905699745486024767e+03 9.903258170298505636e-01 2.348014230792846036e-03 -2.255115158910800074e-04 1.409941745242049987e-03 6.074559491826653890e+00 6.074559491826653890e+00 6.074559491826653890e+00 7.661544053520681246e+02 2.346850261759999778e+00 4.000000000000000000e+01'
#
# During handling of the above exception, another exception occurred:
#
# ValueError       Traceback (most recent call last)
# <ipython-input-2-38fbbc4a2281> in <module>
#      12 #Load of the data
#      13
# ---> 14 Target2 = Target(Location="data", Name="Sp0000+0000", Output="Sp0000+0000", version=0)
#      15 Target2.PreClean(CutOff=7.5, NIter=2, Columns=-1, MinDataCount=50, SavePlot=False, ShowPlot=True)
#      16
#
# /media/prajwal/Elements/Splash/lib/splash.py in __init__(self, Location, Name, Output, version)
#      43             if version==0:
#      44                 print("Loading from txt file.")
# ---> 45                 self.ParamNames, self.ParamValues = ReadTxtData(Location, Name)
#      46             elif version==1 or version==2:
#      47                 print("Loading from fits file.")
#
# /media/prajwal/Elements/Splash/lib/Functions.py in ReadTxtData(Location, TargetName)
#     217             Data = np.loadtxt(FileItem,skiprows=1, delimiter=",")
#     218         except:
# --> 219             Data = np.loadtxt(FileItem, skiprows=0)
#     220
#     221         AllData.extend(Data)
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#    1089             # Then pack it according to the dtype's nesting
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#    1089             # Then pack it according to the dtype's nesting
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in floatconv(x)
#     792         if '0x' in x:
#     793             return float.fromhex(x)
# --> 794         return float(x)
#     795
#     796     typ = dtype.type
#
# ValueError: could not convert string to float: 'TIME'

# %%
#The values are read from search.ini file
SVDSearch.transitSearchParam['TStepSize'] = 3.0 #in Minutes
SVDSearch.transitSearchParam['TDurStepSize'] = 5.0 #in Minutes

SVDSearch.Run(Target1, ShowPlot=True, SavePlot=True)
SVDSearch.PeriodicSearch(Target1, method="TLS", ShowPlot=True)
SVDSearch.PeriodicSearch(Target1, method="TransitPair", ShowPlot=True)

SVDSearch.Run(Target2, ShowPlot=True, SavePlot=True)
SVDSearch.PeriodicSearch(Target2, method="TLS", ShowPlot=True)
SVDSearch.PeriodicSearch(Target2, method="TransitPair", ShowPlot=True)
# Out:
#   0%|          | 0/338 [00:00<?, ?it/s]
# Running 1 Night
# 100%|██████████| 338/338 [01:20<00:00,  4.22it/s]
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   0%|          | 0/338 [00:00<?, ?it/s]
# Running 2 Night
# 100%|██████████| 338/338 [01:20<00:00,  4.21it/s]
#   0%|          | 0/345 [00:00<?, ?it/s]
# Running 3 Night
#  18%|█▊        | 63/345 [00:15<01:07,  4.19it/s]

# %%
# Out:
#   0%|          | 0/335 periods | 00:00<?
# Now running TLS
# Transit Least Squares TLS 1.0.24 (21 November 2019)
# Creating model cache for 67 durations
# Searching 2194 data points, 335 periods from 0.601 to 2.09 days
# Using all 24 CPU threads
# 100%|██████████| 335/335 periods | 00:02<00:00
